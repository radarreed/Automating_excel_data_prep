# %% [markdown]
# # Automating excel files to databases

# %%
import pandas as pd
import io
import requests
import re
import numpy as np
url="http://www.ico.org/historical/1990%20onwards/Excel/1a%20-%20Total%20production.xlsx"
#s=requests.get(url).content
c=pd.read_excel(url, header=3) #Read in data to pandas and eliminate columns before the true headers

# %%
c.columns = ['Crop_year', 'beans']+[x for x in c.columns for x in re.findall(r'^\d{4}', x)] #Clean headers

# %%
c = c.loc[c.iloc[:,2].isna()==False] #eliminate empty rows (white space)

# %%
check_digit = c.loc[c.Crop_year.str.contains('total', flags=re.I,regex=True),'1990':].sum() #used to tie out once finished

# %%
c = c.loc[~c.Crop_year.str.contains('total', flags=re.I,regex=True),:] #eliminate totals columns

# %%
c.insert(1, 'Harvest_Month', np.nan)

# %%
x = c[c.beans.isna()==True].index #Get indexes of subheaders
c.loc[x,'Harvest_Month'] = c.Crop_year.loc[c.beans.isna()==True] #move subheaders to new column 'Harvest_Month'
c.Harvest_Month = c.Harvest_Month.fillna(method='ffill') #forward fill harvest month assignments
c.Harvest_Month = [x.split(' ')[0] for x in c.Harvest_Month] #remove the word 'group' (optional step)
c = c.loc[~c.Crop_year.str.contains('group', flags=re.I,regex=True),:] #drop total rows containing subheader

# %%
c.Harvest_Month = [x.split(' ')[0] for x in c.Harvest_Month]

# %%
c
# Out:
#                            Crop_year Harvest_Month  beans        1990  \
# 2                             Angola         April  (R/A)     79.3450
# 3   Bolivia (Plurinational State of)         April    (A)    111.9770
# 4                             Brazil         April  (A/R)  17862.6286
# 5                            Burundi         April  (A/R)    412.3930
# 6                            Ecuador         April  (A/R)   1627.7780
# 7                          Indonesia         April  (R/A)   6720.3830
# 8                         Madagascar         April    (R)    726.4470
# 9                             Malawi         April    (A)    103.6280
# 10                  Papua New Guinea         April  (A/R)   1012.8410
# 11                          Paraguay         April    (A)    168.6270
# 12                              Peru         April    (A)   1003.6320
# 13                            Rwanda         April    (A)    658.8750
# 14                       Timor-Leste         April    (A)      0.0000
# 15                          Zimbabwe         April    (A)    285.7010
# 18                             Congo          July    (R)      0.9240
# 19                              Cuba          July    (A)    177.9120
# 20                Dominican Republic          July  (A/R)    480.0620
# 21                             Haiti          July    (A)    189.8800
# 22                       Philippines          July  (R/A)    132.6320
# 23                          Tanzania          July  (A/R)    969.7260
# 24                            Zambia          July    (A)     22.1860
# 27                             Benin       October    (R)      0.0000
# 28                          Cameroon       October  (R/A)   1857.1840
# 29          Central African Republic       October    (R)    143.2740
# 30                          Colombia       October    (A)  12212.3870
# 31                        Costa Rica       October    (A)   2409.8850
# 32                     Côte d'Ivoire       October    (R)   4334.3630
# 33      Democratic Republic of Congo       October  (R/A)   1479.2960
# 34                       El Salvador       October    (A)   2017.5640
# 35                 Equatorial Guinea       October    (R)      1.5360
# 36                          Ethiopia       October    (A)    849.4510
# 37                             Gabon       October    (R)      1.7080
# 38                             Ghana       October    (R)     14.8550
# 39                         Guatemala       October  (A/R)   2802.9720
# 40                            Guinea       October    (R)     54.4600
# 41                            Guyana       October    (R)      0.3665
# 42                          Honduras       October    (A)   1427.0020
# 43                             India       October  (R/A)   1510.6870
# 44                           Jamaica       October    (A)     15.5740
# # Make a function and automate the rest of the files

# %%
Total_production = 'http://www.ico.org/historical/1990%20onwards/Excel/1a%20-%20Total%20production.xlsx'
domestic_consumption = 'http://www.ico.org/historical/1990%20onwards/Excel/1b%20-%20Domestic%20consumption.xlsx'
Exportable_production = 'http://www.ico.org/historical/1990%20onwards/Excel/1c%20-%20Exportable%20production.xlsx'
Gross_opening_stocks = 'http://www.ico.org/historical/1990%20onwards/Excel/1d%20-%20Gross%20Opening%20stocks.xlsx'
Exports = 'http://www.ico.org/historical/1990%20onwards/Excel/1e%20-%20Exports%20-%20crop%20year.xlsx'
filelist = [Total_production, domestic_consumption, Exportable_production, Gross_opening_stocks, Exports]
filenames = ['Total_production', 'domestic_consumption', 'Exportable_production', 'Gross_opening_stocks', 'Exports']

# %%
path = 'C:/Users/erler/OneDrive/Documents/Random Data Sets/coffee/Finished/Python_method/'
tables = {}
for j,g in enumerate(filelist):    
    c=pd.read_excel(g, header=3) #Read in data to pandas and eliminate columns before the true headers
    c.columns = ['Crop_year', 'beans']+[x for x in c.columns for x in re.findall(r'^\d{4}', x)] #Clean headers 
    c = c.loc[c.iloc[:,2].isna()==False] #eliminate empty rows (white space)
    check_digit = c.loc[c.Crop_year.str.contains('total', flags=re.I,regex=True),'1990':].sum() #used to tie out once finished
    c = c.loc[~c.Crop_year.str.contains('total', flags=re.I,regex=True),:] #eliminate totals columns
    c.insert(1, 'Harvest_Month', np.nan)
    x = c[c.beans.isna()==True].index #Get indexes of subheaders
    c.loc[x,'Harvest_Month'] = c.Crop_year.loc[c.beans.isna()==True] #move subheaders to new column 'Harvest_Month'
    c.Harvest_Month = c.Harvest_Month.fillna(method='ffill') #forward fill harvest month assignments
    c = c.loc[~c.Crop_year.str.contains('group', flags=re.I,regex=True),:] #drop total rows containing subheader
    print(filenames[j]+' variance:', c.iloc[:,3:].sum().sum()-check_digit.sum()) #check for variance   
    c.to_csv(path+str(filenames[j])+'.csv') #save to folder 
    tables[filenames[j]] = c #make dict of all tables
# Out:
# Total_production variance: -9606.0
# domestic_consumption variance: -4809.0
# Exportable_production variance: -4991.0
# Gross_opening_stocks variance: 0.0
# Exports variance: -113435.00639999984

# %%
tables['Total_production']
# Out:
#                            Crop_year  Harvest_Month  beans        1990  \
# 2                             Angola    April group  (R/A)     50.3450
# 3   Bolivia (Plurinational State of)    April group    (A)    122.7770
# 4                             Brazil    April group  (A/R)  27285.6286
# 5                            Burundi    April group  (A/R)    487.3930
# 6                            Ecuador    April group  (A/R)   1503.8150
# 7                          Indonesia    April group  (R/A)   7441.3830
# 8                         Madagascar    April group    (R)    982.4470
# 9                             Malawi    April group    (A)    104.6280
# 10                  Papua New Guinea    April group  (A/R)    962.8410
# 11                          Paraguay    April group    (A)    130.6270
# 12                              Peru    April group    (A)    936.6320
# 13                            Rwanda    April group    (A)    534.8750
# 14                       Timor-Leste    April group    (A)      0.0000
# 15                          Zimbabwe    April group    (A)    251.9010
# 18                             Congo     July group    (R)      2.9240
# 19                              Cuba     July group    (A)    414.2120
# 20                Dominican Republic     July group  (A/R)    880.0620
# 21                             Haiti     July group    (A)    392.8800
# 22                       Philippines     July group  (R/A)    973.6320
# 23                          Tanzania     July group  (A/R)    931.7790
# 24                            Zambia     July group    (A)     22.6860
# 27                             Benin  October group    (R)      0.0000
# 28                          Cameroon  October group  (R/A)   1682.4840
# 29          Central African Republic  October group    (R)    175.2740
# 30                          Colombia  October group    (A)  14396.0000
# 31                        Costa Rica  October group    (A)   2561.8850
# 32                     Côte d'Ivoire  October group    (R)   2940.3630
# 33      Democratic Republic of Congo  October group  (R/A)   1580.2960
# 34                       El Salvador  October group    (A)   2464.8640
# 35                 Equatorial Guinea  October group    (R)      3.5360
# 36                          Ethiopia  October group    (A)   2909.4510
# 37                             Gabon  October group    (R)      3.4080
# 38                             Ghana  October group    (R)     37.8550
# 39                         Guatemala  October group  (A/R)   3270.5290
# 40                            Guinea  October group    (R)     44.4600
# 41                            Guyana  October group    (R)      0.0000
# 42                          Honduras  October group    (A)   1567.9580
# 43                             India  October group  (R/A)   2828.6870
# 44                           Jamaica  October group    (A)     22.5740
# 45                             Kenya  October group    (A)   1485.1350
# 46  Lao People's Democratic Republic  October group    (R)      0.0000
# 47                           Liberia  October group    (R)      3.0000
# 48                            Mexico  October group  (A/R)   4674.2450
# 49                             Nepal  October group    (A)      0.0000
# 50                         Nicaragua  October group    (A)    461.0780
# 51                           Nigeria  October group    (R)     29.1900
# 52                            Panama  October group    (A)    214.9870
# 53                      Sierra Leone  October group    (R)     42.7830
# 54                         Sri Lanka  October group  (R/A)     95.8700
# 55                          Thailand  October group  (R/A)    757.0170
# 56                              Togo  October group    (R)    161.3080
# 57                 Trinidad & Tobago  October group    (R)     14.5810
# 58                            Uganda  October group  (R/A)   1955.0090
# 59                         Venezuela  October group    (A)   1122.4770
# 60                          Viet Nam  October group  (R/A)   1310.2880
# 61                             Yemen  October group    (A)      0.0000
#
#           1991        1992        1993       1994        1995       1996  ...  \
# 2      79.3310     77.5200     32.6080     76.802     62.1090     70.925  ...
# 3     103.5360    120.2350     50.8230    116.944    142.4850    124.579  ...
# 4   27293.4934  34603.3542  28166.9786  28192.047  18060.2022  29196.743  ...
# 5     667.1990    620.2380    393.3540    664.143    433.9800    400.969  ...
# 6    2123.8240   1185.4800   2069.0070   2375.766   1888.2330   1992.914  ...
# 7    8493.1960   5569.4780   6743.2880   5367.878   4573.4290   8220.584  ...
# 8     932.5130   1121.6840    441.8590    641.372    785.0090    849.008  ...
# 9     124.2860    137.1610     62.1110     84.112     91.2350     48.650  ...
# 10    746.8160    900.1110   1019.4810   1138.659   1002.3630   1089.348  ...
# 11     79.6530     54.2910     70.0460     24.689     22.8430     25.563  ...
# 12   1200.4740   1761.9530    665.4970   1178.628   1870.9390   1805.861  ...
# 13    483.8300    638.8750    443.6250     22.449    329.0780    293.003  ...
# 14      0.0000      0.0000      0.0000      0.000      0.0000      0.000  ...
# 15    201.3940     77.8240     11.6000    106.302    130.6440    174.393  ...
# 18      3.0030      3.1710      3.0000      7.585     11.7550     13.860  ...
# 19    302.0970    284.2370    285.4040    284.315    284.9550    365.865  ...
# 20    320.5600    637.8150    603.9440    729.670    885.6250    518.848  ...
# 21    463.3520    499.8550    450.6970    450.246    513.9450    428.387  ...
# 22   1018.4820    919.8510    874.8550    876.764    849.5900    889.819  ...
